# %%
import google.generativeai as genai

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 50)
print("AI IMAGE PROMPT GENERATOR")
print("=" * 50)

idea = input("Enter Image Idea: ")

prompt = f"""
Create one professional AI image generation prompt.

Image Idea:
{idea}

Make it detailed, realistic and ready to use in
Midjourney, DALL-E or Stable Diffusion.
"""

response = model.generate_content(prompt)

result = response.text

print("\nGenerated Prompt:\n")
print(result)

with open("ImagePrompt.txt", "w", encoding="utf-8") as file:
    file.write(result)

print("\nPrompt saved as ImagePrompt.txt")
# Out:
# ...
# AI IMAGE PROMPT GENERATOR
# ...
# C:\Users\hites\AppData\Local\Temp\ipykernel_19028\1308514955.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Enter Image Idea:  A COW FLY IN SPACE AND EATING GRASS
# Generated Prompt:
#
# Here's one professional AI image generation prompt, detailed and ready for use:
#
# ---
#
# **Prompt:**
#
# ...
