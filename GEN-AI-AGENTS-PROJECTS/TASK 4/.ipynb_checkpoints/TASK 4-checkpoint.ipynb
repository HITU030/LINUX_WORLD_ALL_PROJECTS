# %%
import google.generativeai as genai

# ==========================
# GEMINI API KEY
# ==========================

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 60)
print("PROMPT BASED CODING ASSISTANT")
print("=" * 60)

# ==========================
# USER INPUT
# ==========================

problem = input("Enter Coding Problem: ")

# ==========================
# PROMPT
# ==========================

prompt = f"""
You are an expert coding assistant.

Problem:
{problem}

Generate:

1. Python Code

2. Code Explanation

3. Input Output Example

4. Improvement Suggestions

Keep explanation beginner friendly.
"""

response = model.generate_content(prompt)

result = response.text

print("\n")
print("=" * 60)
print("GENERATED SOLUTION")
print("=" * 60)

print(result)

# ==========================
# SAVE FILE
# ==========================

with open("CodingAssistant.txt", "w", encoding="utf-8") as file:
    file.write(result)

print("\nSolution saved as CodingAssistant.txt")
# Out:
# ...
# PROMPT BASED CODING ASSISTANT
# ...
# C:\Users\hites\AppData\Local\Temp\ipykernel_9488\2923353290.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Enter Coding Problem:  CREATE A CALCULATOR FOR ME
# ...
# GENERATED SOLUTION
# ...
# Here's a simple calculator program in Python, along with explanations, an example, and suggestions for improvement.
#
# ---
#
# ### 1. Python Code
#
# ```python
# # --- 1. Define Basic Math Functions ---
#
# def add(x, y):
#     """Adds two numbers together."""
#     return x + y
#
# def subtract(x, y):
#     """Subtracts the second number from the first."""
#     return x - y
#
# def multiply(x, y):
#     """Multiplies two numbers."""
#     return x * y
#
# ...
