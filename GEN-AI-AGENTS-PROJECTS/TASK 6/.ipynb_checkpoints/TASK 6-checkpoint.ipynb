# %%
import google.generativeai as genai

# ==========================
# GEMINI API KEY
# ==========================

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 60)
print("AI CONTENT CREATION PLATFORM")
print("=" * 60)

# ==========================
# USER INPUT
# ==========================

topic = input("Enter Topic: ")
target_audience = input("Target Audience: ")
tone = input("Tone (Professional/Friendly/Marketing): ")

# ==========================
# PROMPT
# ==========================

prompt = f"""
You are a professional content creator.

Topic:
{topic}

Target Audience:
{target_audience}

Tone:
{tone}

Generate:

1. Blog Article (300-500 words)

2. LinkedIn Post

3. Instagram Caption

4. 10 Relevant Hashtags

5. SEO Keywords

Keep content engaging and professional.
"""

response = model.generate_content(prompt)

content = response.text

print("\n")
print("=" * 60)
print("GENERATED CONTENT")
print("=" * 60)

print(content)

# ==========================
# SAVE FILE
# ==========================

with open("ContentCreation.txt", "w", encoding="utf-8") as file:
    file.write(content)

print("\nContent saved as ContentCreation.txt")
# Out:
# ...
# AI CONTENT CREATION PLATFORM
# ...
# C:\Users\hites\AppData\Local\Temp\ipykernel_4932\3227577900.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Enter Topic:  indian examination system
# Target Audience:  students
# Tone (Professional/Friendly/Marketing):  professional
# ...
# GENERATED CONTENT
# ...
# Here's the content tailored for the Indian examination system, targeting students with a professional tone:
#
# ---
#
# ## 1. Blog Article: Beyond the Marks: Navigating the Indian Examination System with Strategy and Purpose
#
# **Introduction**
#
# ...
