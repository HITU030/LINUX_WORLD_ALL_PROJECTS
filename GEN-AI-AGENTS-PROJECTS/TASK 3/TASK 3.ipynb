# %% [markdown]
# # TASK 3  : AI Study Assistant

# %%
import google.generativeai as genai

# ==========================
# GEMINI API KEY
# ==========================

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 60)
print("AI STUDY ASSISTANT")
print("=" * 60)

# ==========================
# USER INPUT
# ==========================

topic = input("Enter Topic Name: ")

print("\nPaste Your Notes Below:")
notes = input()

# ==========================
# PROMPT
# ==========================

prompt = f"""
You are an AI Study Assistant.

Topic:
{topic}

Notes:
{notes}

Generate:

1. Short Summary

2. Important Points

3. 5 Flashcards

4. 5 Multiple Choice Questions
   with answers

5. Study Tips

Keep everything easy to understand.
"""

response = model.generate_content(prompt)

result = response.text

print("\n")
print("=" * 60)
print("AI STUDY MATERIAL")
print("=" * 60)

print(result)

# ==========================
# SAVE FILE
# ==========================

with open("GENRATED_NOTES.txt", "w", encoding="utf-8") as file:
    file.write(result)

print("\nStudy Material saved as StudyAssistant.txt")
# Out:
# ...
# AI STUDY ASSISTANT
# ...
# C:\Users\hites\AppData\Local\Temp\ipykernel_18180\3291738702.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Enter Topic Name:  MACHINE LEARNING
# Paste Your Notes Below:
#  Notes.pdf
# ...
# AI STUDY MATERIAL
# ...
# Hello! As your AI Study Assistant, I'll generate some helpful materials for your Machine Learning topic.
#
# Since I don't have access to the "Notes.pdf" you mentioned, I'll generate content based on general, foundational concepts of Machine Learning.
#
# ---
#
# ### Machine Learning Study Guide
#
# Here's your study material:
#
# ---
#
# ### 1. Short Summary
#
# ...
