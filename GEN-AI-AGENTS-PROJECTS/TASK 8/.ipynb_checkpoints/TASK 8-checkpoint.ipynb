# %%
import google.generativeai as genai

# ==========================
# GEMINI API KEY
# ==========================

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 60)
print("AI CODE ASSISTANT TOOL")
print("=" * 60)

print("""
1. Generate Code
2. Explain Code
3. Debug Code
4. Optimize Code
5. Generate Documentation
""")

choice = input("Choose Option: ")

print("\nPaste Code / Problem Statement:")
content = input()

# ==========================
# MODE
# ==========================

modes = {
    "1": "Generate Python Code",
    "2": "Explain Code",
    "3": "Debug Code",
    "4": "Optimize Code",
    "5": "Generate Documentation"
}

selected_mode = modes.get(choice)

# ==========================
# PROMPT
# ==========================

prompt = f"""
Mode:
{selected_mode}

User Content:
{content}

Instructions:

If Generate Code:
- Generate complete Python code.

If Explain Code:
- Explain line by line.

If Debug Code:
- Find errors.
- Provide corrected code.

If Optimize Code:
- Improve efficiency.
- Explain improvements.

If Generate Documentation:
- Generate professional documentation.

Keep explanation beginner friendly.
"""

response = model.generate_content(prompt)

result = response.text

print("\n")
print("=" * 60)
print("AI CODE ASSISTANT OUTPUT")
print("=" * 60)

print(result)

# ==========================
# SAVE FILE
# ==========================

with open("CodeAssistantReport.txt", "w", encoding="utf-8") as file:
    file.write(result)

print("\nReport saved as CodeAssistantReport.txt")
# Out:
# ...
# AI CODE ASSISTANT TOOL
# ...
#
# 1. Generate Code
# 2. Explain Code
# 3. Debug Code
# 4. Optimize Code
# 5. Generate Documentation
# C:\Users\hites\AppData\Local\Temp\ipykernel_13488\2950146207.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Choose Option:  1
# Paste Code / Problem Statement:
#  full code for a calculator
# ...
# AI CODE ASSISTANT OUTPUT
# ...
# ```python
# # --- Simple Python Calculator ---
#
# def add(x, y):
#     """Adds two numbers and returns the sum."""
#     return x + y
#
# def subtract(x, y):
#     """Subtracts two numbers and returns the difference."""
#     return x - y
#
# def multiply(x, y):
#     """Multiplies two numbers and returns the product."""
# ...
