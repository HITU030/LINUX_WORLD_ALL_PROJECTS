# %% [markdown]
# # TASK 5  : AI Email Automation System

# %%
import google.generativeai as genai

# ==========================
# GEMINI API KEY
# ==========================

genai.configure(api_key="AQ.Ab8RN6KkiSjuWMORG7txBAhOu1ExCza6fZIvs6iuePdqp91aYw")

model = genai.GenerativeModel("gemini-2.5-flash")

print("=" * 60)
print("AI EMAIL AUTOMATION SYSTEM")
print("=" * 60)

print("""
1. HR Email
2. Job Application
3. Leave Request
4. Sales Email
5. Customer Support Email
6. Custom Email
""")

choice = input("Choose Email Type: ")

name = input("Your Name: ")
recipient = input("Recipient Name: ")
company = input("Company Name: ")
purpose = input("Purpose of Email: ")

# ==========================
# PROMPT
# ==========================

prompt = f"""
Generate a professional email.

Email Type:
{choice}

Sender:
{name}

Recipient:
{recipient}

Company:
{company}

Purpose:
{purpose}

Generate:

1. Subject Line
2. Email Body
3. Professional Closing
4. Signature

Keep it professional.
"""

response = model.generate_content(prompt)

email_text = response.text

print("\n")
print("=" * 60)
print("GENERATED EMAIL")
print("=" * 60)

print(email_text)

# ==========================
# SAVE FILE
# ==========================

with open("GeneratedEmail.txt", "w", encoding="utf-8") as file:
    file.write(email_text)

print("\nEmail saved as GeneratedEmail.txt")
# Out:
# ...
# AI EMAIL AUTOMATION SYSTEM
# ...
#
# 1. HR Email
# 2. Job Application
# 3. Leave Request
# 4. Sales Email
# 5. Customer Support Email
# 6. Custom Email
# C:\Users\hites\AppData\Local\Temp\ipykernel_14380\3461945458.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# Choose Email Type:  HR Email
# Your Name:  hitesh
# Recipient Name:  himanshu
# Company Name:  hiteshtravels pvt. ltd.
# Purpose of Email:  job
# ...
# GENERATED EMAIL
# ...
# Subject: Interview Invitation: Travel Consultant Position - hiteshtravels pvt. ltd.
#
# Dear Himanshu,
#
# ...
