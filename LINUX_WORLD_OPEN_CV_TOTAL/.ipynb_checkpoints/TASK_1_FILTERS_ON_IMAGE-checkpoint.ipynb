# %%
import cv2
import matplotlib.pyplot as plt
image_path = input("ENTER path for input image: ")
image = cv2.imread(image_path)
while True:

    print("""
    ===== choose onne filter =====

    1. grey
    2. Blur
    3. Blue 
    4. Green 
    5. Red 
    6. Yellow 
    7. Purple
    8. Cyan 
    9. Orange
    10. Exit
    """)

    choice = int(input("Enter your choice: "))

    if choice == 1:

        result = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    elif choice == 2:

        result = cv2.GaussianBlur(image, (15, 15), 0)

    elif choice == 3:
        overlay = image.copy()
        overlay[:] = (255, 0, 0)
        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 4:
        overlay = image.copy()
        overlay[:] = (0, 255, 0)
        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 5:
        overlay = image.copy()
        overlay[:] = (0, 0, 255)
        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 6:
        overlay = image.copy()
        overlay[:] = (0, 255, 255)

        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 7:
        overlay = image.copy()
        overlay[:] = (255, 0, 255)

        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 8:

        overlay = image.copy()
        overlay[:] = (255, 255, 0)
        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    elif choice == 9:

        overlay = image.copy()
        overlay[:] = (0, 165, 255)
        result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)
        
    elif choice == 10:
        print("exitttt")
        break

    else:
        print("Invalid Choice")
        continue
        
    plt.imshow(result)
    plt.axis("off")
    plt.show()

    save = input("Do you want to save image (y/n): ")

    if save.lower() == "y":

        file_name = input("Enter output file name: (jpg/png also) ")

        cv2.imwrite(file_name, result)

        print("Image Saved Successfully")
